# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv')

# %%
df.head(20)
# Out:
#     engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                   170            3.0       159.0     3413.433759
# 1                   130            5.0        97.0     3149.664934
# 2                   170            NaN        78.0     3079.038997
# 3                   220            4.0         NaN     2542.392402
# 4                   210            1.0       140.0     3460.870990
# 5                   190            3.0         NaN     2484.883986
# 6                   240            7.0       127.0     3006.542287
# 7                   150            4.0       239.0     3638.657780
# 8                   250            1.0       174.0     2714.219310
# 9                   150            4.0       123.0     3509.036569
# 10                  230            5.0       100.0     3111.810181
# 11                  150            5.0         NaN     1967.200421
# 12                  320            5.0       145.0     2783.868974
# ...

# %%
# Q1
pd.__version__
# Out:
# '2.3.2'

# %%
# Q2
count = len(df)
print(count)
# Out:
# 9704

# %%
# Q3
fuel_type_num = df['fuel_type'].nunique()
print(fuel_type_num)
# Out:
# 2

# %%
# Q4
missing_counts = df.isna().sum()
print(missing_counts)
columns_with_missing = missing_counts[missing_counts > 0]
print(columns_with_missing)
num_columns_with_missing = len(columns_with_missing)
print(num_columns_with_missing)
# Out:
# engine_displacement      0
# num_cylinders          482
# horsepower             708
# vehicle_weight           0
# acceleration           930
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors              502
# fuel_efficiency_mpg      0
# dtype: int64
# num_cylinders    482
# horsepower       708
# acceleration     930
# num_doors        502
# dtype: int64
# 4

# %%
# Q5
asia = df[df['origin'] == 'Asia']
# print(asia)
asian_fuel = asia['fuel_efficiency_mpg'].max()
print(asian_fuel)
# print(df)
# Out:
# 23.759122836520497

# %%
# Q6

horsepower_median = df['horsepower'].median()
horsepower_mode = df['horsepower'].mode()

print(type(horsepower_mode[0]))

missing_counts = df['horsepower'].isna().sum()

print(horsepower_median, horsepower_mode)

print("this is missing_counts", missing_counts)

new_df = df['horsepower'].copy()
print(new_df)

new_df = new_df.fillna(horsepower_mode[0])


print(new_df)

missing_counts = new_df.isna().sum()
print("this is new missing_counts", missing_counts)


new_horsepower_median = new_df.median()

# # missing_counts = df['horsepower'].isna().sum()

print("!!!ans", new_horsepower_median)
# # print("this is new missing_counts", missing_counts)
# Out:
# <class 'numpy.float64'>
# 149.0 0    152.0
# Name: horsepower, dtype: float64
# this is missing_counts 708
# 0       159.0
# 1        97.0
# 2        78.0
# 3         NaN
# 4       140.0
#         ...
# 9699    164.0
# 9700    154.0
# 9701    138.0
# 9702    177.0
# 9703    140.0
# Name: horsepower, Length: 9704, dtype: float64
# 0       159.0
# 1        97.0
# 2        78.0
# 3       152.0
# 4       140.0
#         ...
# 9699    164.0
# 9700    154.0
# 9701    138.0
# 9702    177.0
# 9703    140.0
# Name: horsepower, Length: 9704, dtype: float64
# this is new missing_counts 0
# !!!ans 152.0

# %%
# Q7
asia_cars = df[df['origin'] == 'Asia']
a_vm = asia_cars[['vehicle_weight','model_year']]
# print(a_vm)

f7 = a_vm.head(7)
print(f7)

import numpy as np

x = f7.to_numpy()
print('nf7', nf7)

xt = x.T
print('x', x)

xtx = xt @ x
print('xtx', xtx)

# test = np.dot(nf7, x)
# print('test', test)

y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

xtx_in = np.linalg.inv(xtx)

w = xtx_in @ xt @ y

print(w)

ans = w.sum()

print(ans)
# Out:
#     vehicle_weight  model_year
# 8      2714.219310        2016
# 12     2783.868974        2010
# 14     3582.687368        2007
# 20     2231.808142        2011
# 21     2659.431451        2016
# 34     2844.227534        2014
# 38     3761.994038        2019
# nf7 [[2714.21930965 2016.        ]
#  [2783.86897424 2010.        ]
#  [3582.68736772 2007.        ]
#  [2231.8081416  2011.        ]
#  [2659.43145076 2016.        ]
#  [2844.22753389 2014.        ]
#  [3761.99403819 2019.        ]]
# x [[2714.21930965 2016.        ]
#  [2783.86897424 2010.        ]
#  [3582.68736772 2007.        ]
#  [2231.8081416  2011.        ]
#  [2659.43145076 2016.        ]
#  [2844.22753389 2014.        ]
#  [3761.99403819 2019.        ]]
# xtx [[62248334.33150762 41431216.50732678]
#  [41431216.50732678 28373339.        ]]
# [0.01386421 0.5049067 ]
# 0.5187709081074007
